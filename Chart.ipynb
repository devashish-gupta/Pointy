# %%
import numpy as np

# %%
train_accs = list(np.load("train_accs.npy"))
val_accs = list(np.load("val_accs.npy"))
train_loss = list(np.load("train_losses.npy"))

# %%
train_accs = []+train_accs
val_a

# %%
y
# Out:
# array([0.71341463, 0.75020325, 0.77855691, 0.80081301, 0.80894309,
#        0.81941057, 0.83424797, 0.84044715, 0.8472561 , 0.86087398,
#        0.86036585, 0.87184959, 0.875     , 0.88038618, 0.88658537,
#        0.89197154, 0.88871951, 0.89684959, 0.89969512, 0.90223577,
#        0.90660569, 0.90650407, 0.90833333, 0.91331301, 0.91626016,
#        0.91615854, 0.92469512, 0.91859756, 0.9222561 , 0.92256098,
#        0.92530488, 0.92784553, 0.92591463, 0.92804878, 0.93140244,
#        0.92845528, 0.93546748, 0.93302846, 0.93567073, 0.93506098,
#        0.9375    , 0.94004065, 0.93963415, 0.93831301, 0.94227642,
#        0.9449187 , 0.94461382, 0.94563008, 0.94817073, 0.94918699,
#        0.94827236, 0.94735772, 0.94603659, 0.94664634, 0.94969512,
#        0.95254065, 0.94867886, 0.95111789, 0.95121951, 0.9554878 ,
#        0.95365854, 0.95538618, 0.9578252 , 0.95650407, 0.95813008,
#        0.95833333, 0.95904472, 0.96056911, 0.95965447, 0.96412602,
# ...

# %%
z = np.load("val_accs.npy")

# %%
# Adding for first three epochs from serial output
# Out:
# 147

# %%
z
# Out:
# array([0.78669355, 0.83104839, 0.8358871 , 0.85846774, 0.85685484,
#        0.86572581, 0.87096774, 0.88024194, 0.89717742, 0.8858871 ,
#        0.88790323, 0.89435484, 0.89959677, 0.88064516, 0.90362903,
#        0.89596774, 0.9108871 , 0.90604839, 0.90322581, 0.90040323,
#        0.90887097, 0.90846774, 0.90443548, 0.89959677, 0.91370968,
#        0.90524194, 0.90282258, 0.90483871, 0.90846774, 0.92177419,
#        0.91733871, 0.91169355, 0.90362903, 0.90927419, 0.92298387,
#        0.91491935, 0.91048387, 0.91532258, 0.91491935, 0.91854839,
#        0.92258065, 0.90483871, 0.91370968, 0.92056452, 0.91370968,
#        0.91290323, 0.91532258, 0.91532258, 0.92540323, 0.91572581,
#        0.91814516, 0.90927419, 0.91370968, 0.91572581, 0.91854839,
#        0.92056452, 0.91129032, 0.91169355, 0.91491935, 0.91532258,
#        0.92137097, 0.92016129, 0.92298387, 0.91129032, 0.92137097,
#        0.90524194, 0.92096774, 0.90887097, 0.9233871 , 0.92298387,
# ...

# %%
train_loss
# Out:
# array([2.01634016, 1.93280588, 1.86957578, 1.81920469, 1.79313299,
#        1.77029968, 1.73606503, 1.70995099, 1.70330526, 1.67507604,
#        1.66938167, 1.64708189, 1.63581456, 1.62080997, 1.60708696,
#        1.59974516, 1.59510149, 1.5857187 , 1.57438656, 1.56907431,
#        1.55877237, 1.55616007, 1.55599005, 1.53932172, 1.5317977 ,
#        1.53085819, 1.51910372, 1.52418204, 1.51734716, 1.51335822,
#        1.50715108, 1.5074102 , 1.5027718 , 1.49944039, 1.49241611,
#        1.49506814, 1.48042741, 1.48343561, 1.47896806, 1.47449923,
#        1.47283846, 1.46760467, 1.46764018, 1.47092697, 1.46206766,
#        1.45759323, 1.45211734, 1.45085027, 1.44808873, 1.44479491,
#        0.9449187 , 0.94461382, 0.94563008, 0.94817073, 0.94918699,
#        0.94827236, 0.94735772, 0.94603659, 0.94664634, 0.94969512,
#        0.95254065, 0.94867886, 0.95111789, 0.95121951, 0.9554878 ,
#        0.95365854, 0.95538618, 0.9578252 , 0.95650407, 0.95813008,
#        0.95833333, 0.95904472, 0.96056911, 0.95965447, 0.96412602,
# ...

# %%
train_accs

# %%
val_losses=[3.145631, 2.872256, 2.671589, 2.510723, 2.386101, 2.282701, 2.191863, 2.108063, 2.020145, 1.941974, 1.868074, 1.797904, 1.731497, 1.668461, 1.608447, 1.550356, 1.494295, 1.440111, 1.387896, 1.337707, 1.289488, 1.242994, 1.197823, 1.154745, 1.112838, 1.071812, 1.032102, 0.993209, 0.955642, 0.918853, 0.88302, 0.84841, 0.814663, 0.781645, 0.74951, 0.718023, 0.687623, 0.657905, 0.628743, 0.600162, 0.572644, 0.545927, 0.51997, 0.494737, 0.47031, 0.446559, 0.423792, 0.401816, 0.38079, 0.360591, 0.341078, 0.321999, 0.303899, 0.28656, 0.269979, 0.254058, 0.238974, 0.224384, 0.210599, 0.197387, 0.184902, 0.172638, 0.161265, 0.149951, 0.139419, 0.129332, 0.119901, 0.11096, 0.101881, 0.094109, 0.086735, 0.079678, 0.073045, 0.066704, 0.060718, 0.055057, 0.049697, 0.044792, 0.040084, 0.035674, 0.031704, 0.027924, 0.024406, 0.021129, 0.018148, 0.015382, 0.012982, 0.010879, 0.008973, 0.007322, 0.005913, 0.004746, 0.003824, 0.003052, 0.002417, 0.001926, 0.001564, 0.00132, 0.001198, 0.001201, 0.001332, 0.001598, 0.00199, 0.00251, 0.003188, 0.004011, 0.004971, 0.006087, 0.007357, 0.008787, 0.010367, 0.012105, 0.013997, 0.016054, 0.01829, 0.020705, 0.023303, 0.026085, 0.029054, 0.032211, 0.035559, 0.039]

len(val_losses)
# Out:
# 122

# %%
val_losses_last = []
with open('val_loss_cont.txt','r') as fp:
    data = fp.readlines()
    data  = list(map(lambda x:float(x.rstrip()),data))
    val_losses_last = data

# %%
val_losses.extend(val_losses_last)

# %%
len(val_losses)
# Out:
# 139

# %%
# %cd 3DCTN
# Out:
# [Errno 2] No such file or directory: '3DCTN'
# /home/jupyter/3DCTN

# %%
np.save("train_accs_final.npy",train_accs)
np.save("val_accs_final.npy",val_accs)
np.save("train_loss_final.npy",train_loss)

# %%
train_accs = list(train_accs)
val_accs = list(val_accs)
train_loss = list(train_loss)

# %%
train_accs = [0.393496,0.583537,0.583537 ]+train_accs
val_accs = [0.583537,0.643952,0.736694]+val_accs
train_loss = [2.416582,2.321675,2.1165762]+train_loss

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(train_accs, label='train_accs')
plt.legend()
# plt.ylabel('Loss value')
plt.xlabel('Epoch Number')
plt.title("Training Accuracies for 3DCTN")
plt.show()

# %%
plt.plot(val_accs, label='validation_accs')
plt.legend()
# plt.ylabel('Loss value')
plt.xlabel('Epoch Number')
plt.title("Validation Accuracy for 3DCTN")
plt.show()

# %%
plt.plot(train_loss, label='train_loss')
plt.legend()
plt.ylabel('Loss value')
plt.xlabel('Epoch Number')
plt.title("Training Loss for 3DCTN")
plt.show()
